# %%
RR_connection_latencies = [20.07, 49.36, 65.72, 109.83, 219.87, 339.83]
WRR_connection_latencies = [43.22, 82.96, 99.41, 197.46, 424.99, 549.02]
LT_connection_latencies = [8547.72, 8841.98, 8939.10, 9015.38, 7141.76, 6252.29]
CF_connection_latencies = [43.09, 140.44, 537.08, 897.67, 1382.06, 1521.08]

# %%
RR_connection_throughputs = [499.95, 495.55, 499.9, 499.69, 494.35, 497.11]
WRR_connection_throughputs = [499.94, 499.9, 494.27, 488.07, 487.42, 496.37]
LT_connection_throughputs = [285.26, 261.04, 275.68, 269.08, 260.24, 269.11]
CF_connection_throughputs = [498.43, 499.83, 488.8, 486.3, 471.86, 465.34]

# %%
RR_connection_sockets = [0, 0, 0, 1, 17, 125]
WRR_connection_sockets = [0, 0, 0, 2, 42, 134]
LT_connection_sockets = [0, 1, 2, 57, 355, 1111]
CF_connection_sockets = [0, 0, 0, 19, 117, 366]

# %%
RR_requests_latencies = [2.09, 7612.03, 15106.57, 17472.1, 18727.91, 19416.62]
WRR_requests_latencies = [26.45, 8640.24, 15419.41, 17610.69, 18847.71, 19253.72]
LT_requests_latencies = [12949.28, 16539.68, 18594.89, 19228.81, 19630.37, 19836.68]
CF_requests_latencies = [2172.91, 11172.57, 16425.42, 18276.46, 19103.85, 19680.42]

# %%
RR_requests_throughputs = [499.99, 618.14, 605.96, 606.36, 608.64, 608.02]
WRR_requests_throughputs = [499.99, 576.06, 587.95, 611.85, 599.62, 601.28]
LT_requests_throughputs = [175.71, 177.78, 176.84, 175.76, 178.09, 178.92]
CF_requests_throughputs = [448.36, 442.91, 444.48, 436.2, 436.57, 435.23]

# %%
RR_requests_latencies_10 = [7854.49, 17628.53, 19557.2]
WRR_requests_latencies_10 = [7995.912, 17733.17, 19558.01]
LT_requests_latencies_10 = [17864.43, 19574.78, 20044.182]
CF_requests_latencies_10 = [10973.32, 18335.27, 19725.68]

# %%
RR_requests_throughputs_10 = [602.45, 583.82, 595.77]
WRR_requests_throughputs_10 = [593.86, 593.93, 613.91]
LT_requests_throughputs_10 = [106.2, 106.77, 105.34]
CF_requests_throughputs_10 = [451.39, 444.17, 432.31]

# %%
x_labels_connections = ['10', '20', '25', '50', '100', '200']

# %%
x_labels_requests = ['500', '1000', '2500', '5000', '10000', '25000']

# %%
x_labels_requests_10 = ['1000', '5000', '25000']

# %%
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots()
ax.plot(x_labels_connections, RR_connection_latencies, label='Round Robin')
ax.plot(x_labels_connections, WRR_connection_latencies, label='Weighted Round Robin')
ax.plot(x_labels_connections, LT_connection_latencies, label='Least Time')
ax.plot(x_labels_connections, CF_connection_latencies, label='Chained Failover')
ax.set_title('Latency vs Number of Concurrent Connections')
ax.set_xlabel('Number of Concurrent Connections')
ax.set_ylabel('Latency')
ax.legend()
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot(x_labels_connections, RR_connection_throughputs, label='Round Robin')
ax.plot(x_labels_connections, WRR_connection_throughputs, label='Weighted Round Robin')
ax.plot(x_labels_connections, LT_connection_throughputs, label='Least Time')
ax.plot(x_labels_connections, CF_connection_throughputs, label='Chained Failover')
ax.set_title('Throughput vs Number of Concurrent Connections')
ax.set_xlabel('Number of Concurrent Connections')
ax.set_ylabel('Throughput')
ax.legend()
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot(x_labels_connections, RR_connection_sockets, label='Round Robin')
ax.plot(x_labels_connections, WRR_connection_sockets, label='Weighted Round Robin')
ax.plot(x_labels_connections, LT_connection_sockets, label='Least Time')
ax.plot(x_labels_connections, CF_connection_sockets, label='Chained Failover')
ax.set_title('Number of Socket Errors vs Number of Concurrent Connections')
ax.set_xlabel('Number of Concurrent Connections')
ax.set_ylabel('Number of Socket Errors')
ax.legend()
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot(x_labels_requests, RR_requests_latencies, label='Round Robin')
ax.plot(x_labels_requests, WRR_requests_latencies, label='Weighted Round Robin')
ax.plot(x_labels_requests, LT_requests_latencies, label='Least Time')
ax.plot(x_labels_requests, CF_requests_latencies, label='Chained Failover')
ax.set_title('Latency vs Number of Requests/Sec')
ax.set_xlabel('Number of Requests/Sec')
ax.set_ylabel('Latency')
ax.legend()
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot(x_labels_requests, RR_requests_throughputs, label='Round Robin')
ax.plot(x_labels_requests, WRR_requests_throughputs, label='Weighted Round Robin')
ax.plot(x_labels_requests, LT_requests_throughputs, label='Least Time')
ax.plot(x_labels_requests, CF_requests_throughputs, label='Chained Failover')
ax.set_title('Throughput vs Number of Requests/Sec')
ax.set_xlabel('Number of Requests/Sec')
ax.set_ylabel('Throughput')
ax.legend()
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot(x_labels_requests_10, RR_requests_latencies_10, label='Round Robin')
ax.plot(x_labels_requests_10, WRR_requests_latencies_10, label='Weighted Round Robin')
ax.plot(x_labels_requests_10, LT_requests_latencies_10, label='Least Time')
ax.plot(x_labels_requests_10, CF_requests_latencies_10, label='Chained Failover')
ax.set_title('Latency vs Number of Requests/Sec for 10 Servers')
ax.set_xlabel('Number of Requests/Sec')
ax.set_ylabel('Latency')
ax.legend()
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot(x_labels_requests_10, RR_requests_throughputs_10, label='Round Robin')
ax.plot(x_labels_requests_10, WRR_requests_throughputs_10, label='Weighted Round Robin')
ax.plot(x_labels_requests_10, LT_requests_throughputs_10, label='Least Time')
ax.plot(x_labels_requests_10, CF_requests_throughputs_10, label='Chained Failover')
ax.set_title('Throughput vs Number of Requests/Sec for 10 Servers')
ax.set_xlabel('Number of Requests/Sec')
ax.set_ylabel('Throughput')
ax.legend()
plt.show()
